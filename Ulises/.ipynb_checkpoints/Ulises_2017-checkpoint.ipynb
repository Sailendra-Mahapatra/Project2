# %%
import datetime as dt
import numpy as np
import pandas as pd
import requests
import json
from pprint import pprint
import csv
# from api_key import api_key
from flask_sqlalchemy import SQLAlchemy
from sqlalchemy.ext.automap import automap_base
from sqlalchemy.orm import Session
from sqlalchemy import create_engine

# %%
export_url = (f"https://api.census.gov/data/timeseries/intltrade/exports")
import_url = (f"https://api.census.gov/data/timeseries/intltrade/imports")
china_code = "5700"
usa_code = "1000"
month = []
year = []

# %%
export_by_commodity = requests.get(f"{export_url}/hs?get=E_COMMODITY,E_COMMODITY_SDESC,ALL_VAL_MO,ALL_VAL_YR&time=from+2017-01&COMM_LVL=HS4&CTY_CODE={china_code}").json()

# %%
count = 1
movalue = []
yrvalue = []
period = []
desc = []
code = []
while count < 4745:
    count += 1
    movalue.append(export_by_commodity[count][2])
    yrvalue.append(export_by_commodity[count][3])
    desc.append(export_by_commodity[count][1])
    period.append(export_by_commodity[count][4])
    code.append(export_by_commodity[count][0])
china_data_export = pd.DataFrame({"YTD Value" : yrvalue,
                           "Monthly Value " : movalue,
                          "Period" : period,
                          "Commodity" : desc,
                          "Comm Code": code})

# %%
import_by_commodity = requests.get(f"{import_url}/hs?get=I_COMMODITY,I_COMMODITY_SDESC,GEN_VAL_MO,GEN_VAL_YR&time=from+2017-01&COMM_LVL=HS4&CTY_CODE={china_code}").json()

# %%
count = 1
movalue = []
yrvalue = []
period = []
desc = []
code = []
while count < 4802:
    count += 1
    movalue.append(import_by_commodity[count][2])
    yrvalue.append(import_by_commodity[count][3])
    desc.append(import_by_commodity[count][1])
    period.append(import_by_commodity[count][4])
    code.append(import_by_commodity[count][0])
china_data_import = pd.DataFrame({"YTD Value" : yrvalue,
                           "Monthly Value " : movalue,
                          "Period" : period,
                          "Commodity" : desc,
                          "Comm Code": code})

# %%
china_data_export["YTD Value"] =pd.to_numeric(china_data_export["YTD Value"])

# %%
first_2017 = china_data_export[china_data_export["Period"].str.contains("2017")]

# %%
data_2017 = first_2017.groupby(["Comm Code","Commodity"])["YTD Value"].sum()

# %%
test= pd.DataFrame({"total" : data_2017})

# %%
test
# Out:
#                                                                   total
# Comm Code Commodity
# 0101      HORSES, ASSES, MULES AND HINNIES, LIVE                 110738
# 0102      BOVINE ANIMALS, LIVE                                     8634
# 0103      SWINE, LIVE                                             66396
# 0106      ANIMALS, LIVE, NESOI                                  5497834
# 0202      MEAT OF BOVINE ANIMALS, FROZEN                          60928
# 0203      MEAT OF SWINE (PORK), FRESH, CHILLED OR FROZEN      200033316
# 0204      MEAT OF SHEEP OR GOATS, FRESH, CHILLED OR FROZEN        13552
# 0206      ED OFFAL, BOVINE, SWINE, SHEEP, GOAT, HORSE, ETC.   218000108
# 0207      MEAT & ED OFFAL OF POULTRY, FRESH, CHILL OR FROZEN    1929657
# 0208      MEAT & EDIBLE OFFAL NESOI, FRESH, CHILLD OR FROZEN     306591
# 0209      PIG/POULTRY FAT FRSH CHLD FRZ SALT                    1774601
# 0301      FISH, LIVE                                             458918
# 0302      FISH, FRESH OR CHILLED (NO FILLETS OR OTHER MEAT)        5274
# 0303      FISH, FROZEN (NO FISH FILLETS OR OTHER FISH MEAT)   374173815
# 0304      FISH FILLETS & OTH FISH MEAT, FRESH, CHILL OR FROZ   68548069
# 0305      FISH, DRIED, SALTED ETC, SMOKED ETC; ED FISH MEAL      819999
# 0306      CRUSTACEANS LIVE FRSH ETC S                         247554674
# 0307      MOLLUSCS LIVE FRESH ETC; SMOKED; FLOURS ETC EDI      47109682
# 0308      AQUATIC INVERTEB LIVE ET                              1961163
# 0401      MILK AND CREAM, NOT CONCENTRATED OR SWEETENED          423841
# 0402      MILK AND CREAM, CONCENTRATED OR SWEETENED            73719865
# 0403      BUTTERMILK, YOGURT, KEPHIR ETC, FLAVORD ETC OR NOT     661858
# 0404      WHEY & MILK PRODUCTS, SWEETENED ETC. OR NOT, NESOI  205764706
# 0405      BUTTER AND OTHER FATS AND OILS DERIVED FROM MILK       204975
# 0406      CHEESE AND CURD                                      40399677
# 0408      BIRDS' EGGS, NOT IN SHELL & YOLKS, FRESH,              820035
# 0409      HONEY, NATURAL                                         545279
# 0501      HUMAN HAIR, UNWORKED AND WASTE OF HUMAN HAIR           370805
# 0502      HOGS' HAIR ETC; BADGER HAIR ETC; WASTE HAIR ETC.      1800000
# 0504      ANIMAL (NOT FISH) GUTS, BLADDERS, STO               135669825
# ...                                                                 ...
# 9507      FISHING RODS & TACKLE; NETS; DECOYS ETC; PARTS        2333668
# 9508      MERRY-GO-ROUNDS, OTH FAIRGR                          69646647
# 9602      VEG MOLDED RESIN ETC CARV                              210199
# 9603      BROOMS, BRUSHES, MOPS, FEAT                          13008223
# 9604      HAND SIEVES AND HAND RIDDLES                            52132
# 9605      TRAVEL SETS FOR PERSONAL TOILET,ETC                    382102
# 9606      BUTTONS, PRESS STUDS ETC, BUTTON MOLD & BLANKS ETC    1670478
# 9607      SLIDE FASTENERS AND PARTS THEREOF                      929853
# 9608      PENS (BALL POINT, S TIP ET                            1726518
# 9609      PENCILS (LEAD ENCASED), CRAYONS, LEADS, CHA           1778878
# 9610      SLATES & BOARDS,WITH WRITING OR DRAWING SURFACES       171185
# 9611      DATE SEALING OR NUMBERING                             1550725
# 9612      TYPEWRITER ETC RIBBONS, INKED OR PREP; INK PADS       1043915
# 9613      CIGARETTE LIGHTERS & OTHER LIGHTERS; PARTS NESOI     32795725
# 9614      SMOKING PIPES & BOWLS, CIGAR ETC HOLDERS, & PARTS      102362
# 9615      COMBS, HAIR-SLIDES ETC;                                 88861
# 9616      SCENT & SIMILAR SPRAYERS ETC; P                        866378
# 9617      VACUUM FLASKS & VESSELS W CASES; PTS EX GLSS INNER    1931000
# 9618      TAILORS' DUMMIES & OTHR MANNEQUINS FOR DISPLAY         294055
# 9619      SANITARY TOWELS AND TAMPONS DIAPERS FOR BABIES ETC    2773725
# 9620      MONOPODS, BIPODS, TRIPODS AND SIMILAR ARTICLES          45080
# 9701      PAINTINGS, DRAWINGS ETC BY HAND AS ART; COLLAG ETC   27620785
# 9702      ORIGINAL ENGRAVINGS, PRINTS & LITHOGRAPHS              653617
# 9703      ORIGINAL SCULPTURES AND STATUARY, IN ANY MATERIAL    42539195
# 9705      COLLECTORS ITEMS OF BOTANIC, HISTOR ETC INT           1941215
# 9706      ANTIQUES OF AN AGE EXCEEDING ONE HUNDRED YEARS        1716039
# 9801      EXPTS OF REPAIRED IMPTS; IMPTS O                    523549771
# 9802      EXPTS CHARITY NESOI; IMP                              3793087
# 9803      EXPORTS MILITARY APPAREL & MILITARY EQUIP NOT IDEN     171356
# 9880      LOW VALUE EXP SHP; CANADIAN. EST LATE RECEIPTS      609468401
#
# [1101 rows x 1 columns]

# %%
data_2017= test.nlargest(50,"total")

# %%
data_2017 = data_2017.reset_index()

# %%
data_2017= data_2017.nlargest(50,"total")
data_2017
# Out:
#    Comm Code                                          Commodity        total
# 0       8800              CIVILIAN AIRCRAFT, ENGINES, AND PARTS  12397840093
# 1       1201                    SOYBEANS, WHETHER OR NOT BROKEN  11452198457
# 2       8703                  MOTOR CARS & VEHICLES FOR TRANSPO   7647479820
# 3       8542  ELECTRONIC INTEGRATED CIRCUITS & MICROASSEMBL,...   6064727241
# 4       8486                     MACH/APPS FOR MANUFCT OF SEMIC   3350537037
# 5       2709   CRUDE OIL FROM PETROLEUM AND BITUMINOUS MINERALS   2885922392
# 6       8708                           PARTS & ACCESS FOR MOTOR   2776526227
# 7       9018                          MEDICAL, SURGICAL, DENTAL   2714760232
# 8       4407  WOOD SAWN OR CHIPPED LENGTH, SLICED ETC, OV6MM TH   2037494645
# 9       2711       PETROLEUM GASES & OTHER GASEOUS HYDROCARBONS   1743730219
# 10      4707             WASTE AND SCRAP OF PAPER OR PAPERBOARD   1686362809
# 11      9027                          INST ETC FOR PHYSICAL ETC   1654856865
# 12      8517                    ELECTRIC APPARATUS FOR LINE TEL   1495396207
# 13      4403  WOOD IN THE ROUGH, STRIPPED OR NOT OF SAPWOOD ETC   1485597287
# 14      8471                   AUTOMATIC DATA PROCESS MACHINES;   1428346195
# 15      5201                       COTTON, NOT CARDED OR COMBED   1325966979
# 16      7404                             COPPER WASTE AND SCRAP   1310532959
# 17      1007                                      GRAIN SORGHUM   1241246802
# 18      3907                        POLYETHERS, EXPOXIDES & POL   1176585490
# 19      4101               RAW HIDES & SKINS OF BOVINE OR EQUIN   1141107243
# 20      8481  TAPS, COCKS, VALVES ETC FOR PIPES, TANKS ETC, PTS   1082703133
# 21      7204  FERROUS WASTE & SCRAP; REMELT SCR IRON/STEEL I...   1080218958
# 22      3901             POLYMERS OF ETHYLENE, IN PRIMARY FORMS   1066716528
# 23      2710                          OIL (NOT CRUDE) FROM PETR   1023558894
# 24      4703  CHEMICAL WOODPULP, SODA OR SULFATE, NOT DISSOL...    987548033
# 25      7602                           ALUMINUM WASTE AND SCRAP    887851768
# 26      9030                       OSCILLOSCOPES, SPECTRUM ANAL    844047022
# 27      3002                           HUMAN BLOOD; ANIMAL BLOO    838272274
# 28      9021                     ORTHOPEDIC APPL; ARTIF BODY PT    706559672
# 29      9022                           X-RAY ETC APPARATUS; TUB    686907680
# 30      3920                           PLATES, SHEETS, FILM ETC    660144532
# 31      3815  REACTION INITIATORS & ACCELER & CATALYT PREP N...    636245722
# 32      3004                         MEDICAMENTS NESOI, MIXED O    632095116
# 33      3822  COMPOSITE DIAGNOSTIC/LAB REAGENTS, EXC PHARMACEUT    621829336
# 34      7108   GOLD (INCL PLAT PLATED), UNWR, SEMIMFR OR POWDER    620098251
# 35      9880     LOW VALUE EXP SHP; CANADIAN. EST LATE RECEIPTS    609468401
# 36      1001                                   WHEAT AND MESLIN    577238176
# 37      8421   CENTRIFUGES; FILTER ETC MACH FOR LIQ OR GASES; P    563968309
# 38      3902  POLYMERS OF PROPYLENE OR OTHER OLEFINS, PRIM F...    530132824
# 39      2713  PETROLEUM COKE, PETROLEUM BITUMEN & OTHER RESI...    530075408
# 40      8409                    PARTS FOR ENGINES OF HEADING 84    529124990
# 41      9801                   EXPTS OF REPAIRED IMPTS; IMPTS O    523549771
# 42      2701        COAL; BRIQUETTES, OVOIDS ETC. MFR FROM COAL    515215888
# 43      3904  POLYMERS OF VINYL CHLORIDE ETC., IN PRIMARY FORMS    507032657
# 44      9031  MACHINES, NESOI IN CHAPTER 90; PROFILE PROJECT...    503859644
# 45      8401                   NUCLEAR REACTORS; FUEL ELEM (N-I    503390847
# 46      1214                           RUTABAGAS, HAY, CLOVER &    502126081
# 47      8536                           ELECTRICAL APPARATUS FOR    493701183
# 48      8537                         BOARDS, PANELS ETC ELEC SW    477031610
# 49      8413  PUMPS FOR LIQUIDS; LIQUID ELEVATORS; PARTS THE...    474775013

# %%
data_2017 = data_2017.to_csv("data_2017.csv", index=False)
